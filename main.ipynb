# %% [markdown]
# <a href="https://colab.research.google.com/github/neiltheblue/codetester/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Code Tester**

# %% [markdown]
# TODO
#
# * Setup initial AI connection
# * Make generation call
# * Add gradio basic UI
